# %% [markdown]
# # Introduction to bokeh
#
# ## Picture this, your first basic graph
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# # Creating a basic graph
# ---

# %%
from bokeh.plotting import figure, show, output_notebook

x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = [0.0, 1.0, 1.4, 1.7, 2.0, 2.2, 2.4]

p = figure()

p.line(x_values, y_values)

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e6d292ad-6046-4a45-a410-f576980672d0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0e26821a-1f52-4994-9e63-a57afb80a4b3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0e26821a-1f52-4994-9e63-a57afb80a4b3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0e26821a-1f52-4994-9e63-a57afb80a4b3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0e26821a-1f52-4994-9e63-a57afb80a4b3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5ab0751-67c0-4eaf-aa0d-70a82e565657":{"roots":{"references":[{"attributes":{},"id":"5fcc9236-8cb3-41b0-8e71-402c38695a76","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"d492c383-1220-4bf1-9b97-191cf10113e2","type":"ColumnDataSource"}},"id":"b0df890e-647f-478b-9172-0f6718e71d42","type":"CDSView"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"03db480c-523a-4a6a-9c70-2c8fdd39d9c4","type":"Line"},{"attributes":{"formatter":{"id":"5fcc9236-8cb3-41b0-8e71-402c38695a76","type":"BasicTickFormatter"},"plot":{"id":"aa9b399c-0328-451c-ba2b-4f7d906b9cfe","subtype":"Figure","type":"Plot"},"ticker":{"id":"cd8b0d91-f816-4e44-aff9-8b0ee628ad3c","type":"BasicTicker"}},"id":"74263653-550d-46fa-a0f6-977ad13201c0","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cbfdbbaf-2572-401f-9202-1d6be7ada7ef","type":"Line"},{"attributes":{},"id":"fb19e4ef-da3d-4be4-bb46-a93309627548","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2,3,4,5,6],"y":[0.0,1.0,1.4,1.7,2.0,2.2,2.4]}},"id":"d492c383-1220-4bf1-9b97-191cf10113e2","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"ce8d21a7-5c78-4333-b04e-774417fc55f9","type":"BoxAnnotation"}},"id":"e6e1ba49-5372-4e11-9349-85f5ef867e3a","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"51f343db-d0e6-4f04-b50c-74ac19ed64d5","type":"PanTool"},{"id":"92871cf8-0adf-49c1-b1d0-57c558b1bab0","type":"WheelZoomTool"},{"id":"e6e1ba49-5372-4e11-9349-85f5ef867e3a","type":"BoxZoomTool"},{"id":"fb19e4ef-da3d-4be4-bb46-a93309627548","type":"SaveTool"},{"id":"10ec7310-616c-454d-89af-3f7dde75c235","type":"ResetTool"},{"id":"00029ff1-baf8-4d4a-a936-d6766b09e781","type":"HelpTool"}]},"id":"8a9d1497-4966-44b5-9dfe-b35f013b8d9f","type":"Toolbar"},{"attributes":{},"id":"51f343db-d0e6-4f04-b50c-74ac19ed64d5","type":"PanTool"},{"attributes":{"callback":null},"id":"28af08b7-50a1-40bb-852b-2b2482803d37","type":"DataRange1d"},{"attributes":{"callback":null},"id":"16b08a08-9296-49e4-99bf-186ee80e8d45","type":"DataRange1d"},{"attributes":{},"id":"cd8b0d91-f816-4e44-aff9-8b0ee628ad3c","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"aa9b399c-0328-451c-ba2b-4f7d906b9cfe","subtype":"Figure","type":"Plot"},"ticker":{"id":"cd8b0d91-f816-4e44-aff9-8b0ee628ad3c","type":"BasicTicker"}},"id":"70bbe602-80fa-45ea-9a13-7823b29876d6","type":"Grid"},{"attributes":{},"id":"a419ce85-0608-441d-9617-f9b8200cdecd","type":"BasicTicker"},{"attributes":{},"id":"10ec7310-616c-454d-89af-3f7dde75c235","type":"ResetTool"},{"attributes":{},"id":"92871cf8-0adf-49c1-b1d0-57c558b1bab0","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"34b91be9-e766-4a60-9f7d-5ad145e5ed56","type":"BasicTickFormatter"},"plot":{"id":"aa9b399c-0328-451c-ba2b-4f7d906b9cfe","subtype":"Figure","type":"Plot"},"ticker":{"id":"a419ce85-0608-441d-9617-f9b8200cdecd","type":"BasicTicker"}},"id":"4054b88f-5457-4583-9488-1f785a3add9c","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ce8d21a7-5c78-4333-b04e-774417fc55f9","type":"BoxAnnotation"},{"attributes":{},"id":"f35f9524-2424-4855-9bfd-6c8b863a01fa","type":"LinearScale"},{"attributes":{"data_source":{"id":"d492c383-1220-4bf1-9b97-191cf10113e2","type":"ColumnDataSource"},"glyph":{"id":"03db480c-523a-4a6a-9c70-2c8fdd39d9c4","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cbfdbbaf-2572-401f-9202-1d6be7ada7ef","type":"Line"},"selection_glyph":null,"view":{"id":"b0df890e-647f-478b-9172-0f6718e71 ...

# %% [markdown]
# # Get an error related to numpy?
# ## Are you on Windows?
#
# This [comment thread](https://github.com/ContinuumIO/anaconda-issues/issues/883), albeit related to scipy, may help.

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, try the following experiments:
#
# 1. Add an additional number to `x_values` and to `y_values` and execute the cell (press `Ctrl+Enter`)
# 1. Swap the `x_values` and `y_values` (i.e. change `p.line(...)` to `p.line(y_values, x_values)` and execute the cell
# 1. Add an additional value to the `x_values`, but leave the `y_values` alone, so that the number of elements is no longer the same, and execute the cell

# %% [markdown]
# # Getting help
# ---

# %% [markdown]
# ```python
# object?
# ```
#
# For example:
#
# ```python
# p?
# ```

# %%
p?

# %% [markdown]
# # Don't know what functions are available?
# ---

# %% [markdown]
# `p.<tab-complete>`

# %% [markdown]
# # Want insight into what a _particular_ function can do?
# ---

# %% [markdown]
# `p.line?`

# %%
p.line?

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, use IPython help to read about the `p.line` method:
#
# 1. **DON'T FRET** if some of it feels like gibberish OR certain words or phrases are unclear.
#
# 1. This exercise is more about familiarizing you with what is available. Plus, many of these are found associated with every type of glyph, so you will see them over and over again and your familiarity will grow over time.
#
# 1. **NOTE:** I am not an expert on all of the parameters associated with the various glyphs, so don't fret if there seems to be a lot to learn.

# %% [markdown]
# # Let's do it again, but moar!
# ---
#
# ## with Circles
# ## with Dashes
# ## with Legends

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

moar = figure()

x = np.linspace(0.1, 5, 100)               # figures can handle numpy arrays
y = range(0, 200, 2)                       # and ranges()

# Let's use circular markers and a dotted and dashed line
# AND 
# add a legend with unique entries for each line

moar.circle(x, np.cumsum(x),
            legend="y=cumsum(y)")

moar.line(x, y, 
          legend="y=range(0, 200, 2)",
          line_color="#663399", line_dash="dotdash")

# And add a legend created from the legend attributes of each item

moar.legend.location = "top_left"

output_notebook()
show(moar)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1e9077d7-3d20-4f8a-bc24-8650cca48110">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"e32237e7-6eb8-4544-8e96-b9c836e7c12d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3189a439-634c-40ee-b6ec-79786e94ac3e","type":"BasicTicker"}},"id":"4b4d603a-a864-4a15-98e5-482cbfa259b7","type":"Grid"},{"attributes":{},"id":"5d4bfa26-a404-43aa-b4c1-f8866d201b2a","type":"HelpTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f11a04a3-dfbd-44d5-ad99-3fd0df11f7c9","type":"Circle"},{"attributes":{"overlay":{"id":"6d8c4ddc-ec74-44e3-9c81-254dc5eabee1","type":"BoxAnnotation"}},"id":"a0eb514a-bff7-429a-a80e-4b5f2f8c6d0d","type":"BoxZoomTool"},{"attributes":{"source":{"id":"508c3827-190 ...

# %% [markdown]
# # How to learn more, in these notebooks
# ---

# %% [markdown]
# 1. Select the cell in the notebook that contains something you want to learn more about
# 1. Click the `Insert cell below` button (the `plus` sign) on the Jupyter toolbar to make an empty cell
# <img src='./images/jupyter_toolbar.png' width='300' style="float:center"><br>
# 1. Inspect the variables and methods/functions
#    * `print()` the variable (or a subset of the variable)
#    * Use the `type()` function to figure out what type of object you have
#    * Use the question mark help functionality (`object?`) to learn more about the object
#    * Tweak something, see what happens.

# %% [markdown]
# # Moarest! adding multiple features to a basic graph
# ---

# %%
# Experiment
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Colors
#
# Bokeh has rich support for colors using the most common color schemas.
#
# * any of the 147 named CSS colors, e.g `green`, `indigo`, `purple`
# * hex values: Red, Green, Blue (optional Alpha) >>> RGB(A) e.g., `#FF0000`, `#44444444`
# * a 3-tuple of integers (R, G, B) between 0 and 255
# * a 4-tuple of (R, G, B, A) where R, G, B are integers between 0 and 255 and A is a floating point value between 0 and 1
#
# ## What colors and color names?
# [https://en.wikipedia.org/wiki/Web_colors](https://en.wikipedia.org/wiki/Web_colors)

# %%
from bokeh.plotting import figure, show, output_file, output_notebook
import numpy as np

x = np.linspace(0.1, 5, 100)
y = x

# Add a title
# Define the type of y-axis
# Set the range of values for the y-axis

p = figure(title="log axis example", 
           y_axis_type="log", y_range=(0.001, 10**22))

# %%
# Set the fill color for our circles to None

p.circle(x, y**2, legend="y=x**2", 
         fill_color=None, 
         line_color="blueviolet", size=5)
# Out:
# GlyphRenderer(id='537f4768-acab-4322-957b-9923f3d09953', ...)

# %%
# Create a line
# Set the line width to 4

p.line(x, 10**y, legend="y=10^x", line_color="darkred", 
       line_width=2)
# Out:
# GlyphRenderer(id='eea7e34a-459a-472e-804d-6bd997a68443', ...)

# %%
# Add a line composed of squares
# Use hex this time to color the line

p.square(x, 10**(x**2), legend="y=10^(x^2)",
       line_color="#663399", 
       line_dash="solid", line_width=2)
# Out:
# GlyphRenderer(id='ccf0ef83-d58f-45e6-afe6-71ff1a381628', ...)

# %%
# Move the legend location
# Change the legend font

p.legend.location = "center_left"
p.legend.label_text_font='times'

# Change characteristics of the title text (color, font, font-style)
# Using RGB tuple this time

p.title.text_font_size = '16pt'
p.title.text_color = (125, 125, 125)
p.title.text_font = "courier"
p.title.text_font_style = "bold"

# Set the background color

p.background_fill_color = "whitesmoke"

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="
},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"57124352-a702-4b75-9197-6cea414fd6d3","type":"ColumnDataSource"},{"attributes":{},"id":"15ed0d97-7d30-49d6-9f53-cd317efef28d","type":"WheelZoomTool"},{"attributes":{"items":[{"id":"666b68a0-13cb-4f84-8db0-46271b0ba4c4","type":"LegendItem"},{"id":"b94c38aa-f932-4c89-9fa5-8dcee5360ad6","type":"LegendItem"},{"id":"ca98a9c2-a423-4a34-a117-e0d1f01d042d","type":"LegendItem"}],"label_text_font":"times","location":"center_left","plot":{"id":"6c73f80f-ac9e-4d8e-a8c0-64ad249c1d64","subtype":"Figure","type":"Plot"}},"id":"53eb53fb-eb00-4d2b-a283-cbd4f39c5f9c","type":"Legend"},{"attributes":{"source":{"id":"6086731a-cc2c-4d0a-89c6-a0de76d403b2","type":"ColumnDataSource"}},"id":"668dddc4-6e44-440b-86d9-be8766ec7f41","type":"CDSView"},{"attributes":{"num_minor_ticks":10},"id":"04a311c1-00b8-4f03-9f67-9a4ff906a687","type":"LogTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"8065a688-5a8c-418c-a479-d1f2c8792920","type":"ColumnDataSource"},{"attributes":{"label":{"value":"y=10^x"},"renderers":[{"id":"eea7e34a-459a-472e-804d-6bd997a68443","type":"GlyphRenderer"}]},"id":"b94c38aa-f932-4c89-9fa5-8dcee5360ad6","type":"LegendItem"},{"attribut ...

# %% [markdown]
# # Color Palettes
# ---

# %% [markdown]
# http://bokeh.pydata.org/en/latest/docs/reference/palettes.html
#
# <img src='./images/purples.png' height='250' width='300' style="float:right">

# %%
from bokeh.palettes import Purples

# Internally, palettes such as Purples are stored as dictionaries:

# Key: integer indicating how many colors are in a sub palette
# Value: list of strings indicating the actual color values 

print(Purples[3], Purples[5], sep='\n', end='\n\n')

line_color = Purples[5][1]      # '#756bb1'

print("line_color:", line_color)
# Out:
# ['#756bb1', '#bcbddc', '#efedf5']
# ['#54278f', '#756bb1', '#9e9ac8', '#cbc9e2', '#f2f0f7']
#
# line_color: #756bb1

# %%
# Let's add a new line to the figure
# This one will use a dot-dash appearance and
# the color we chose above, from the Palette

p.line(x, np.sqrt(x) * 100, 
       legend="y=sqrt(x)", 
       line_color=line_color, 
       line_dash="dotdash", 
       line_width=3)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c62f8a15-9f02-4f91-9892-d8b3a7ad7a85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c62f8a15-9f02-4f91-9892-d8b3a7ad7a85");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c62f8a15-9f02-4f91-9892-d8b3a7ad7a85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c62f8a15-9f02-4f91-9892-d8b3a7ad7a85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c24360bc-28fa-4cdd-b112-304c35c3632b":{"roots":{"references":[{"attributes":{},"id":"b3841527-0d3d-44f2-8a2a-2b1e16a5480e","type":"LogScale"},{"attributes":{"overlay":{"id":"8827a497-d3d3-4470-9a70-41d55461e5f9","type":"BoxAnnotation"}},"id":"07631d9c-c09e-4807-b5ca-bc73b2cc8bc7","type":"BoxZoomTool"},{"attributes":{},"id":"589d5819-842c-4589-8b59-4a6eeca710a4","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fbc2a513-5bb5-4ef9-81f1-fb8ebb8a96a4","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4,6,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"98aaa112-a0f4-4d82-95c9-03a7a5e87041","type":"Line"},{"attributes":{},"id":"9282589f-78a4-4952-9670-4d6e6c3233d8","type":"ResetTool"},{"attributes":{"source":{"id":"57124352-a702-4b75-9197-6cea414fd6d3","type":"ColumnDataSource"}},"id":"d396447e-ab6c-4bfa-ac78-350008a90696","type":"CDSView"},{"attributes":{"source":{"id":"391ed371-8ed1-4cad-8904-bd2548743bcd","type":"ColumnDataSource"}},"id":"26581d03-8aab-463b-82e9-06f0bc1af3da","type":"CDSView"},{"attributes":{"formatter":{"id":"8680cf3f-2f1b-4e2b-9754-6d9179aaf5e3","type":"LogTickFormatter"},"plot":{"id":"6c73f80f-ac9e-4d8e-a8c0-64ad249c1d64","subtype":"Figure","type":"Plot"},"ticker":{"id":"04a311c1-00b8-4f03-9f67-9a4ff906a687","type":"LogTicker"}},"id":"c0a62907-d2b3-4b05-9b77-0946d440411a","type":"LogAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#663399"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a49a5279-0165-4f06-b2b5-83817c0475fb","type":"Square"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"57124352-a702-4b75-9197-6cea414fd6d3","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"darkred"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b52709e-6cfc-427a-b800-4465bfc50e7d","type":"Line"},{"attributes":{"items":[{"id":"666b68a0-13cb-4f84-8db0-46271b0ba4c4","type":"LegendItem"},{"id":"b94c38aa-f932-4c89-9fa5-8dcee5360ad6","type":"LegendItem"},{"id":"ca98a9c2-a423-4a34-a117-e0d1f01d042d","type":"LegendItem"},{"id":"00949135-9ca1-4233-b15c-66444249ce82","type":"LegendItem"}],"label_text_font":"times","location":"center_left","plot":{"id":"6c73f80f-ac9e-4d8e-a8c0-64ad249c1d64","subtype":"Figure","type":"Plot"}},"id":"53eb53fb-eb00-4d2b-a283-cbd4f39c5f9c","type":"Legend"},{"attributes":{"source":{"id":"6086731a-cc2c-4d0a-89c6-a0de76d403b2","type":"ColumnDataSource"}},"id":"668dddc4-6e44-440b-86d9-be8766ec7f41","type":"CDSView"},{"attributes":{"num_minor_ticks":10},"id":"04a311c1-00b8-4f03-9f67-9a4ff906a687","type":"LogTicker"},{"attributes":{"data_source":{"id":"8065a688-5a8c-418c-a479-d1f2c8792920","type":"ColumnDataSource"},"glyph":{"id":"4b52709e-6cfc-427a-b800-4465bfc50e7d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fbc2a513-5bb5-4ef9-81f1-fb8ebb8a96a4","type":"Line"},"selection_glyph":null,"view":{"id":"5d4236b7-f38c-4af4-8630-3db05ce3a8df","type":"CDSView"}},"id":"eea7e34a-459a-472e-804d-6bd997a68443","type":"GlyphRenderer"},{"attributes":{"label":{"value":"y=10^x"},"renderers":[{"id":"eea7e34a-459a-472e-804d-6bd997a68443","type":"GlyphRenderer"}]},"id":"b94c38aa-f932-4c89-9fa5-8dcee5360ad6","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"6086731a-cc2c-4d0a-89c6-a0de76d403b2","type":"ColumnDataSource"},{"attributes":{"source":{"id":"8065a688-5a8c-418c-a479-d1f2c8792920","type":"ColumnDataSource"}},"id":"5d4236b7-f38c-4af4-8630-3db05ce3a8df","type":"CDSView"},{"attributes":{ ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [History](./history.ipynb) | [Table of Contents](./README.md) | [Five Fun Examples](./five_fun.ipynb) >>> |
