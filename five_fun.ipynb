# %% [markdown]
# # Introduction to bokeh
#
# ## Top 5 fun and entertaining plots
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Next, we will take a look at five sample plots include many diverse examples of how bokeh can be used for awesome data visualizations.
#    0. **scatterplot**
#    1. **histogram** with pdf and cdf curves
#    2. graph with **interactive sliders** to set parameters
#    3. **visualization tools**: pan, zoom, hover, crosshairs, lasso select, box select, poly select, save, undo, redo, tap
#    4. **geographical map**
#
#
# This material is based largely upon the sample graphs shown here:
# http://bokeh.pydata.org/en/latest/docs/gallery.html

# %% [markdown]
# # Sample data for your amusement is available:

# %% [markdown]
# Bokeh comes preinstalled with various types of sample data: look in the site-packages folder found in your virtual environment folder...
#
# `<path_to_where_you_installed_miniconda>/miniconda3/envs/bokeh_tut/lib/python3.5/site-packages/bokeh/sampledata/`
#
# Bokeh provides ready access to some of the smaller datasets via import, as we will see.
#
# There are other much larger datasets available as well, that we will be using and will get later, using:
#
# `bokeh.sampledata.download()`

# %% [markdown]
# # Simple scatterplot
# ---
#
# <img src='./images/220px-Iris_versicolor_3.jpg' height='250' width='300' style="float:right">

# %%
# Let's start by importing some of the data

from bokeh.plotting import figure, show, output_notebook
from bokeh.sampledata.iris import flowers

# When flowers is imported, it comes in as a pandas DataFrame
# DataFrames have a function called sample, that will let us see a representative
#     sample of all the data... let's look at 10 rows.

print(type(flowers))
print(len(flowers))
flowers.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 150
#      sepal_length  sepal_width  petal_length  petal_width     species
# 22            4.6          3.6           1.0          0.2      setosa
# 97            6.2          2.9           4.3          1.3  versicolor
# 106           4.9          2.5           4.5          1.7   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 56            6.3          3.3           4.7          1.6  versicolor
# 118           7.7          2.6           6.9          2.3   virginica
# 18            5.7          3.8           1.7          0.3      setosa
# 67            5.8          2.7           4.1          1.0  versicolor
# 42            4.4          3.2           1.3          0.2      setosa
# 40            5.0          3.5           1.3          0.3      setosa

# %%
# Next, we will prep some enrichments that we can apply to our flower data
# We want to map the species of iris to a color so we create a dict.

colormap = {'setosa': 'red',
            'versicolor': 'green',
            'virginica': 'blue'}

# Then we create a list of colors... one color for each row in the flowers DataFrame.
# Based on the species in the species column, we insert the appropriate color
# into our list.

colors = [colormap[x] for x in flowers['species']]

# To see the results of our work, let's look at a sampling of the colors list.

print(len(colors))
colors[::10]
# Out:
# 150
# ['red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue']

# %%
p = figure(title = "Iris Morphology")

p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"],      # x values
         flowers["petal_width"],       # y values
         color=colors, 
         fill_alpha=0.2, 
         size=10)
# Out:
# GlyphRenderer(id='f4a11c51-98e7-4229-8ba3-58021c4d2ed5', ...)

# %%
output_notebook()
show(p)

# http://bokeh.pydata.org/en/latest/docs/gallery/iris.html
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f2297291-6cb6-48e8-8f78-9c347e3ca4be">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ae64aec9-f0dd-467f-ac48-3d2df2ffa977"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ae64aec9-f0dd-467f-ac48-3d2df2ffa977");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ae64aec9-f0dd-467f-ac48-3d2df2ffa977");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ae64aec9-f0dd-467f-ac48-3d2df2ffa977' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"392d93c5-32b0-4d94-ac59-ea9e91dbc3ed":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a6d37180-e302-49d6-95cc-4d72bc75b3c0","type":"Circle"},{"attributes":{},"id":"d4dcbbf8-b5e5-4950-b27b-8050f112c4f2","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y","line_color","fill_color"],"data":{"fill_color":["red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue"],"line_color":["red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","green","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue","blue"],"x":{"__ndarray__":"...","dtype":"float64","shape":[150]},"y":{"__ndarray__":"...","dtype":"float64","shape":[150]}}},"id":"f8130785-7682-4c81-8d85-69d43e3a5341","type":"ColumnDataSource"},{"attributes":{},"id":"64f09b4b-b5e4-426c-b7eb-bff6dfbd3fa2","type":"LinearScale"},{"attributes":{},"id":"e15bdfca-eea7-4fb5-90dc-340a254e1fb8","type":"SaveTool"},{"attributes":{"overlay":{"id":"a2c2df9c-c6da-45d3-9185-e419978179f6","type":"BoxAnnotation"}},"id":"b779eb33-9be5-422b-8696-5311ea7c861f","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"aa3bce44-89a4-41d5-a5b3-239d2a7674de","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d8343e4-6742-4a70-8ccc-1c484089e597","type":"Circle"},{"attributes":{},"id":"5e0a5ef8-08c5-400a-a36f-d02f29579ab0","type":"BasicTicker"},{"attributes":{},"id":"e824a183-b3b1-4025-bef0-855727aa01b7","type":"WheelZoomTool"},{"attributes":{},"id":"65a81848-bca9-4c5e-8d0a-028f4438fe9d","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Petal Width","formatter":{"id":"65a81848-bca9-4c5e-8d0a-028f4438fe9d","type":"BasicTickFormatter"},"plot":{"id":"32736f77-0df4-4ea3-a2f7-b5defccaff0e","subtype":"Figure","type":"Plot"},"tick ...

# %% [markdown]
# # Workflow
# ---

# %% [markdown]
# As we look at the remaining examples, and as you create your own, a generic, but useful workflow is listed below. Following a workflow such as this, helps you to focus on one task at a time and create robust and easy to understand scripts.
#
# 1. Import libraries
# 1. Generate a figure
# 1. Create or load data and enrichments
# 1. Generate glyphs
# 1. Add attributes, annotations, interactions
# 1. Create outputs
#
# **NOTES**:
#
# * You may not need some steps in the above workflow, especially for barebones charts.
# * Conversely, your charts may be very sophisticated and you may need to expand on the above workflow.
# * This is intended as a starting point.
# * Your mileage may vary (YMMV)!

# %% [markdown]
# # Histogram: with pdf and cdf curves
# ---

# %%
# IMPORTS ---------------------------------------

import numpy as np
import scipy.special

from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_notebook

# %%
# GENERATE FIGURE -----------------------------------------

h = figure(title="Normal Distribution (μ=0, σ=0.5)",
            tools="save",
            background_fill_color="whitesmoke")

# Notice this creates a figure() object

h
# Out:
# Figure(id='d7f52dc4-57b6-4e35-ba7d-76ad67442dbf', ...)

# %% [markdown]
# ```
# h?
# ```
#
# versus
#
# ```
# h??
# ```

# %%
h??

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

# set the midpoint and spread of the data
mu, sigma = 0, 0.5

# draw a 1000 random samples from a normal distribution 
measured = np.random.normal(mu, sigma, 1000)

# compute the histogram of a set of data.
#     hist is an array of the y-values of the histogram points
#     edges is an array of the 'sides' of the rectangles as 
#     defined across the x-axis
hist, edges = np.histogram(measured, density=True, bins=50)

# create an array of x-values: 1000 values between -2 and 2
x = np.linspace(-2, 2, 1000)

# calculate the points for a pdf and a cdf based on:
#     * mu
#     * sigma
#     * the values of x
pdf = 1/(sigma * np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2 / (2*sigma**2))
cdf = (1+scipy.special.erf((x-mu)/np.sqrt(2*sigma**2)))/2

print('MEASURED: ', measured[:10])
print()
print('HIST: ', len(hist), hist[:10])
print()
print('EDGES: ', len(edges), edges[:10])
print()
print('-' * 60, end='\n\n')
print('PDF: ', pdf[:10])
print()
print('CDF: ', cdf[:10])
# Out:
# MEASURED:  [ 0.46407007  0.43983954 -0.02807296 -0.61490776 -0.3110148  -1.18520233
#   0.39089448  1.30624794 -0.44793081  0.63121352]
#
# HIST:  50 [ 0.01486284  0.02972569  0.          0.          0.          0.02972569
#   0.01486284  0.          0.          0.02972569]
#
# EDGES:  51 [-1.8014972  -1.73421531 -1.66693343 -1.59965155 -1.53236967 -1.46508779
#  -1.39780591 -1.33052403 -1.26324215 -1.19596027]
#
# ------------------------------------------------------------
#
# PDF:  [ 0.00026766  0.00027636  0.00028533  0.00029457  0.00030409  0.0003139
#   0.000324    0.00033441  0.00034513  0.00035617]
#
# CDF:  [  3.16712418e-05   3.27602929e-05   3.38847210e-05   3.50456008e-05
#    3.62440370e-05   3.74811655e-05   3.87581535e-05   4.00762007e-05
#    4.14365401e-05   4.28404387e-05]

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. In the code cell below, use `?` to explore the `quad()` function assocated with the figure `h`
# 1. What is the default fill_color?
# 1. What does the characteristic `alpha` do?
# 1. How does `alpha` contrast with `line_alpha`?

# %%
# Let's look into the quad() method of our figure:

# %%
# GENERATE GLYPHS -----------------------------------------

h.quad(top=hist,
       bottom=0,
       left=edges[:-1],
       right=edges[1:],
       fill_color='yellow', alpha=0.9, line_color="orange")
# Out:
# GlyphRenderer(id='c6e49448-9fe5-4bfe-a3b3-3c657a87fe30', ...)

# %%
# GENERATE GLYPHS (cont.)-----------------------------------

h.line(x, pdf, line_color="black", line_width=3, alpha=0.7, legend="PDF")
h.line(x, cdf, line_color="red", line_width=2, alpha=0.7, legend="CDF")
# Out:
# GlyphRenderer(id='404496a0-82b2-45bc-a124-8a21f87ed737', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

h.legend.location = "top_left"
h.xaxis.axis_label = 'x'
h.yaxis.axis_label = 'Pr(x)'

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(h)

# http://bokeh.pydata.org/en/latest/docs/gallery/histogram.html
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ce898f4b-bd05-4cfc-a59f-68160cde191c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ee62e1cc-cec8-4eb3-99f2-00a3c2ea0337"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ee62e1cc-cec8-4eb3-99f2-00a3c2ea0337");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee62e1cc-cec8-4eb3-99f2-00a3c2ea0337");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee62e1cc-cec8-4eb3-99f2-00a3c2ea0337' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb310cdf-e541-4322-95da-b1cce2418cd7","type":"Line"},{"attributes":{},"id":"91811f8a-2e2b-499e-a73a-114d73e245af","type":"BasicTickFormatter"},{"attributes":{"background_fill_color":{"value":"whitesmoke"},"below":[{"id":"eef556c1-2f4d-424f-91be-9dd945d93b78","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"28213091-c906-497a-b796-1c0477602967","type":"LinearAxis"}],"renderers":[{"id":"eef556c1-2f4d-424f-91be-9dd945d93b78","type":"LinearAxis"},{"id":"5dd6c961-458e-46ae-a1e2-21d5e1446fa4","type":"Grid"},{"id":"28213091-c906-497a-b796-1c0477602967","type":"LinearAxis"},{"id":"e6b26e5b-ce08-419d-bb21-a9b17b2196eb","type":"Grid"},{"id":"c6e49448-9fe5-4bfe-a3b3-3c657a87fe30","type":"GlyphRenderer"},{"id":"854e7bad-bf9c-4fb6-bfbd-e94e4475f6fd","type":"Legend"},{"i ...

# %% [markdown]
# # Using interactive sliders
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np

from bokeh.layouts import row, widgetbox

from bokeh.models import CustomJS, Slider

from bokeh.plotting import figure, output_notebook, show, ColumnDataSource

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# # Try to identify the purpose of these two functions:
#
# 1. CustomJS
# 1. Slider

# %%
# GENERATE FIGURE -----------------------------------------
plot = figure(y_range=(-10, 10), plot_width=400, plot_height=400)

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------
x = np.linspace(0, 10, 500)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# %%
# GENERATE GLYPHS -----------------------------------------
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)
# Out:
# GlyphRenderer(id='9c3c44b0-6ffc-443c-97bb-641ce0d8d0bc', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------
# I am not a javascript guru.
# ... you are on your own in terms of making javascript


callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var A = amp.value;
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = A*Math.sin(x[i]);
    }
    source.trigger('change');
    """)

amp_slider = Slider(start=0.1, end=10, value=1, step=.1,
                    title="Amplitude",
                    callback=callback)

callback.args["amp"] = amp_slider

layout = row(plot,
             widgetbox(amp_slider))

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(layout)

# http://bokeh.pydata.org/en/latest/docs/gallery/slider.html
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33b2fd9d-7790-44d7-8c1a-8562cd379f05">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6df940fa-fd92-46dd-ace0-1b74f39b0d9c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6df940fa-fd92-46dd-ace0-1b74f39b0d9c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6df940fa-fd92-46dd-ace0-1b74f39b0d9c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6df940fa-fd92-46dd-ace0-1b74f39b0d9c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"16084456-9a35-4feb-9a55-46a331004d8f":{"roots":{"references":[{"attributes":{},"id":"bf3ce95e-9532-4169-944e-1024e055ed7e","type":"BasicTicker"},{"attributes":{"data_source":{"id":"53a31043-e536-4f2b-bdff-60e1c5b7b2bf","type":"ColumnDataSource"},"glyph":{"id":"53045ce0-df2a-45cc-86d0-9e2f970c16ef","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8652a569-3090-4816-9a2a-6741f937eee7","type":"Line"},"selection_glyph":null,"view":{"id":"e25153cf-12c5-4773-9837-b4f071995fe0","type":"CDSView"}},"id":"9c3c44b0-6ffc-443c-97bb-641ce0d8d0bc","type":"GlyphRenderer"},{"attributes":{"args":{"amp":{"id":"9cbb1037-b7f8-47ff-97a1-6253fd9f7923","type":"Slider"},"source":{"id":"53a31043-e536-4f2b-bdff-60e1c5b7b2bf","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var A = amp.value;\n    x = data['x']\n    y = data['y']\n    for (i = 0; i < x.length; i++) {\n        y[i] = A*Math.sin(x[i]);\n    }\n    source.trigger('change');\n    "},"id":"895f2e11-5e40-4f4e-84dd-a932d9379da2","type":"CustomJS"},{"attributes":{"callback":null},"id":"398b1554-097b-41d2-9959-a8ef8a755d58","type":"DataRange1d"},{"attributes":{"callback":null,"end":10,"start":-10},"id":"261ee821-7b92-4284-b4da-88073210c2e8","type":"Range1d"},{"attributes":{},"id":"2d8af250-4a53-4d43-a085-cf4aff55b6ff","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"e8b59f0a-b1a0-4fd5-be01-0c18493a6197","subtype":"Figure","type":"Plot"},{"id":"ef34a014-493a-4fdb-86f5-6091b460b174","type":"WidgetBox"}]},"id":"e34beaa1-1876-4278-8eff-ee1169bd74c3","type":"Row"},{"attributes":{"overlay":{"id":"789bf35c-646b-4ee0-9930-c207505e2fe0","type":"BoxAnnotation"}},"id":"c972ca24-6f99-4728-b8c3-1ab44e98a1b9","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"53045ce0-df2a-45cc-86d0-9e2f970c16ef","type":"Line"},{"attributes":{"plot":{"id":"e8b59f0a-b1a0-4fd5-be01-0c18493a6197","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf3ce95e-9532-4169-944e-1024e055ed7e","type":"BasicTicker"}},"id":"056beab4-530f-4309-adbf-80d54d76a4c5","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"8652a569-3090-4816-9a2a-6741f937eee7","type":"Line"},{"attributes":{"source":{"id":"53a31043-e536-4f2b-bdff-60e1c5b7b2bf","type":"ColumnDataSource"}},"id":"e25153cf-12c5-4773-9837-b4f071995fe0","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"53a31043-e536-4f2b-bdff-60e1c5b7b2bf","type":"ColumnDataSource"},{"attributes":{},"id":"d4946e5f-085e-44ba-8b0d-0af7e977ea23","type":"LinearScale"},{"attributes":{},"id":"4a96e39a-d103-4265-a0ad-77ff05b4ab19","type":"BasicTicker"},{"attributes":{"formatter":{"id":"7226740b-33dd-4a09-8702-f262f46c775b","type":"BasicTickFormatter"},"plot":{"id":"e8b59f0a-b1a0-4fd5-be01-0c18493a6197","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf3ce95e-9532-4169-944e-1024e055ed7e","type":"BasicTicker"}},"id":"47729f71-9707-4a03-b8fd-4cf2d02d849f","type":"LinearAxis"},{"attributes":{},"id":"0936423c-ebf4-4f98-8033-f9283ab0dac6","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"e8b59f0a-b1a0-4fd5-be01-0c18493a6197","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a96e39a-d103-4265-a0ad-77ff05b4ab19","type":"BasicTicker"}},"id":"20da3491-b1c4-4587-a063-7fb0d6553401","type":"Grid"},{"attributes":{"below":[{"id":"47729f71-9707-4a03-b8fd-4cf2d02d849f","type":"LinearAxis"}],"left":[{"id":"3b55917a-afa7-425c-848c-deafce02295a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"47729f71-9707-4a03-b8fd-4cf2d02d849f","type":"LinearAxis"},{"id":"056beab4-530f-4309-adbf-80d54d76a4c5","type":"Grid"},{"id":"3b55917a-afa7-42 ...

# %% [markdown]
# # Using visualization tools
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

number = 4000
x = np.random.random(size=number) * 100     # random yields [0.0, 1.0) OR 0.0 <= x < 1.0
y = np.random.random(size=number) * 100

radii = np.random.random(size=number) * 1.5

# The following string formatting produces a hex number:
# %02x yields a zero padded hex number when you provide an integer
#     "#%02x" % (int(10)) would yield #0a
#     "#%02x%02x%02x" % (int(10), int(11), 150) would yield #0a0b96

colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS="crosshair,hover,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select"

p = figure(tools=TOOLS)

# GENERATE GLYPHS -----------------------------------------

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)


# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(p)  # open a browser

# http://bokeh.pydata.org/en/latest/docs/gallery/color_scatter.html
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bdfcf3ad-3d76-4874-8654-c3fa229cea5b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d1c5f15a-4785-4c6d-ac78-a64038aa2969"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d1c5f15a-4785-4c6d-ac78-a64038aa2969");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1c5f15a-4785-4c6d-ac78-a64038aa2969");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1c5f15a-4785-4c6d-ac78-a64038aa2969' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"72d7c190-70b4-4fe7-ab71-f58b457a7a80":{"roots":{"references":[{"attributes":{},"id":"0098aaee-64f0-4218-904e-36ba2f873c10","type":"BasicTickFormatter"},{"attributes":{},"id":"5bf1533e-5a12-4f66-84cc-7fe9a818a83e","type":"UndoTool"},{"attributes":{},"id":"9b2b6f6a-68c4-488f-812d-f4adcc1d488c","type":"ResetTool"},{"attributes":{"callback":null},"id":"8e9a3b5d-631d-4802-bd95-eb045aa35ab2","type":"DataRange1d"},{"attributes":{},"id":"c9358ab9-cbc0-4300-b506-de277ee318e4","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"5255e768-d3d5-4027-bc39-33c7a56c2299","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x","radius","fill_color"],"data":{"fill_color":["#7cc296","#716396","#7e9a96","#cfe396","#813396","#91de96","#cb7096","#bfbf96","#ce9f96","#e7a696","#849c96","#b2da96","#d7c696","#8a8f96","#e86c96","#bd6e96","#5be196","#bd3d96","#729c96","#da4196","#cd2f96","#a2b896","#ebd296","#56ba96","#de5196","#979a96","#bc4696","#a82996","#e17896","#b6bb96","#439f96","#cdae96","#cc8396","#bfc496","#d41e96","#917896","#52c096","#7b9496","#accd96","#79a896","#f07f96","#9e2096","#435796","#c75096","#9d3196","#c0b496","#574396","#81c996","#ab2d96","#668096","#398196","#dc6496","#c56396","#ebc796","#696696","#a7cf96
# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# Edit the code cell above to experiment with tool settings:
#
# 1. Add an **additional** `pan` tool to the TOOLS string and execute the code
#    * Consider the warning you get
#    * Look at the toolbar, anyway
#    * Remove the extra `pan` tool
# 1. Add the tool: `poly_select` to the TOOLS string and execute the code
# 1. Add the tool: `lasso_select` to the TOOLS string and execute the code

# %% [markdown]
# # Geographical map
# ---

# %%
# For larger datasets, we will need to download the data 

# The data will be stored in the following location:
# $home_directory/.bokeh/data

import bokeh
bokeh.sampledata.download()

# %%
# IMPORTS -------------------------------------------------

from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)

from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure, output_notebook


from bokeh.sampledata.us_counties import data as counties
from bokeh.sampledata.unemployment import data as unemployment

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"

texas = figure(title="Texas Unemployment, 2009", 
               tools=TOOLS, 
               x_axis_location=None,
               y_axis_location=None)

texas.grid.grid_line_color = None

# %%
# Let's understand the data:
# Looking at just the first 20 keys from the counties data, we see that they are 
# tuples with the first number equal to 48
# the second number is an odd number

print(sorted(counties.keys())[:20])       
print()

# Looking at just one set of data for the county 
# coded with tuple 48, 3, we see that the data is a state, some lats and longs and some names.

print(counties[(48,3)])

# %%
# Looking at the data for unemployment:
# Each key is a tuple, some of which match the tuples for the counties
# Each tuple is paired with an unemployment value.

for key, value in sorted(unemployment.items()):
    if key[0] == 48:
        print('{}: {}'.format(key, value))

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

palette.reverse()

counties = {
    code: county for code, county in counties.items() if county["state"] == "tx"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment[county_id] for county_id in counties]


# LogColorMapper will map numbers in a range [low, high] against a
# sequence of colors (i.e. a palette) on a natural logarithm scale.

color_mapper = LogColorMapper(palette=palette)

# ColumnDataSource() maps the names of columns to sequences or arrays,
# often using a dictionary OR DataFrame. Here we map all the values 
# of county_xs to a variable called x, etc.

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

# %%
# GENERATE GLYPHS -----------------------------------------

# Here, we are referring to the 'x' and 'y' data found in the 
# ColumnDataSource we just created.
# Note that we use the string 'x' NOT x

texas.patches('x', 'y', source=source,
              fill_color={'field': 'rate', 'transform': color_mapper},
              fill_alpha=0.7, line_color="white", line_width=0.5)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

hover = texas.select_one(HoverTool)

hover.point_policy = "follow_mouse"

hover.tooltips = [("Name", "@name"),
                  ("Unemployment rate)", "@rate%"),
                  ("(Long, Lat)", "($x, $y)"),]

# %%
# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(texas)

# http://bokeh.pydata.org/en/latest/docs/gallery/texas.html

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. On the Internets, research the syntax for generating tool tips.

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [First Graph](./first_graph.ipynb) | [Table of Contents](./README.md) | [What Went Wrong](./what_went_wrong.ipynb) >>> |
